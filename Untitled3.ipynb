# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version=1)

# %%
x = mnist["data"]
y = mnist["target"]

# %%
y = y.astype(int)

# %%
print(x.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %%
some_digit = x.iloc[0].values.reshape(28,28)

plt.imshow(some_digit, cmap="binary")
plt.axis("off")
plt.show()

# %%
x_train = x[:60000]
x_test = x[60000:]

y_train = y[:60000]
y_test = y[60000:]

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Acurácia:", accuracy)
# Out:
# Acurácia: 0.9688

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
      "n_neighbors": [3,4,5],
      "weights": ["uniform", "distance"]
              }

# %%
grid_search = GridSearchCV(knn, param_grid, cv=3, verbose=3)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV 1/3] END ....n_neighbors=3, weights=uniform;, score=0.969 total time= 1.3min
# [CV 2/3] END ....n_neighbors=3, weights=uniform;, score=0.968 total time=  57.6s
# [CV 3/3] END ....n_neighbors=3, weights=uniform;, score=0.968 total time=  55.4s
# [CV 1/3] END ...n_neighbors=3, weights=distance;, score=0.970 total time=  56.1s
# [CV 2/3] END ...n_neighbors=3, weights=distance;, score=0.969 total time=  55.3s
# [CV 3/3] END ...n_neighbors=3, weights=distance;, score=0.969 total time=  56.8s
# [CV 1/3] END ....n_neighbors=4, weights=uniform;, score=0.966 total time=  55.5s
# [CV 2/3] END ....n_neighbors=4, weights=uniform;, score=0.966 total time=  55.1s
# [CV 3/3] END ....n_neighbors=4, weights=uniform;, score=0.967 total time=  54.4s
# [CV 1/3] END ...n_neighbors=4, weights=distance;, score=0.971 total time=  55.2s
# [CV 2/3] END ...n_neighbors=4, weights=distance;, score=0.970 total time=  55.3s
# [CV 3/3] END ...n_neighbors=4, weights=distance;, score=0.970 total time=  55.1s
# [CV 1/3] END ....n_neighbors=5, weights=uniform;, score=0.968 total time=  55.5s
# [CV 2/3] END ....n_neighbors=5, weights=uniform;, score=0.967 total time=  55.1s
# [CV 3/3] END ....n_neighbors=5, weights=uniform;, score=0.968 total time=  54.9s
# [CV 1/3] END ...n_neighbors=5, weights=distance;, score=0.969 total time=  55.7s
# [CV 2/3] END ...n_neighbors=5, weights=distance;, score=0.968 total time=  55.7s
# [CV 3/3] END ...n_neighbors=5, weights=distance;, score=0.969 total time=  55.8s
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 4, 5],
#                          'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
print(grid_search.best_params_)
# Out:
# {'n_neighbors': 4, 'weights': 'distance'}

# %%
best_model = grid_search.best_estimator_

y_pred = best_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Acurácia Final:", accuracy)
# Out:
# Acurácia Final: 0.9714
